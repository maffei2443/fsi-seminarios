# %% [markdown]
# # Seminário prático - Experimentos sobre meta-aprendizado

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score,recall_score, f1_score, classification_report, plot_confusion_matrix
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt
import pandas_datareader.data as pdr
from sklearn.datasets import load_iris
from aux import preprocess_default, ALL_ACC, ALL_ACC_SET, drop_draw_set_class, drop_all_vs_rf, print_counter
from itertools import combinations
from sklearn.model_selection import StratifiedKFold

# %%
data = pd.read_csv("meta-base.csv")
data
# Out:
#      general.attrToInst  general.catToNum  general.freqClass.mean  \
# 0              0.100000          0.000000                     0.5
# 1              0.042056          0.000000                     0.5
# 2              0.121622          5.000000                     0.5
# 3              0.492063          0.148148                     0.5
# 4              0.020833          0.000000                     0.5
# ..                  ...               ...                     ...
# 395            0.223881          0.071429                     0.5
# 396            0.003472          0.000000                     0.5
# 397            0.021277          0.000000                     0.5
# 398            0.023500          0.000000                     0.5
# 399            0.006400          0.000000                     0.5
#
#      general.freqClass.sd  general.instToAttr  general.nrAttr  general.nrBin  \
# 0                0.471405           10.000000              60              0
# 1                0.204863           23.777778               9              0
# 2                0.066888            8.222222              18              9
# 3                0.145911            2.032258              31              0
# 4                0.105224           48.000000               7              2
# ..                    ...                 ...             ...            ...
# 395              0.158307            4.466667              15              1
# 396              0.283170          288.000000               6              0
# 397              0.342688           47.000000              18              0
# 398              0.565685           42.553191              47              0
# 399              0.055437          156.250000               4              0
#
#      general.nrCat  general.nrClass  general.nrInst  ...  C4.5.auc   kNN.acc  \
# 0                0                2             600  ...  0.993992  1.000000
# 1                0                2             214  ...  0.786753  0.789214
# 2               15                2             148  ...  0.813973  0.807071
# 3                4                2              63  ...  0.662129  0.663429
# 4                0                2             336  ...  0.959853  0.942531
# ..             ...              ...             ...  ...       ...       ...
# 395              1                2              67  ...  0.779784  0.768214
# 396              6                2            1728  ...  0.982767  0.877835
# 397              0                2             846  ...  0.969553  0.970795
# 398              0                2            2000  ...  0.981546  0.993950
# 399              0                2             625  ...  0.835646  0.858469
#
#       kNN.f1m   kNN.auc   SVM.acc   SVM.f1m   SVM.auc    RF.acc    RF.f1m  \
# 0    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    0.764841  0.879050  0.770022  0.733372  0.835946  0.848485  0.822825
# 2    0.803779  0.887428  0.846863  0.843160  0.927110  0.866887  0.861265
# 3    0.680036  0.749489  0.761619  0.750802  0.827020  0.785238  0.771251
# 4    0.941450  0.977326  0.966627  0.965831  0.985190  0.965199  0.964476
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.757795  0.843975  0.697202  0.701777  0.808815  0.798333  0.784645
# 396  0.844500  0.955360  0.957931  0.950636  0.993741  0.989701  0.987869
# 397  0.962234  0.993139  0.979193  0.972641  0.996332  0.986998  0.982835
# 398  0.983220  0.998558  0.994550  0.984556  0.999174  0.988250  0.965376
# 399  0.857016  0.960794  0.973110  0.972841  0.996881  0.888952  0.887862
#
#        RF.auc
# 0    1.000000
# 1    0.916196
# 2    0.941109
# 3    0.833724
# 4    0.987683
# ..        ...
# 395  0.858558
# 396  0.999346
# 397  0.998817
# 398  0.998578
# 399  0.973667
#
# [400 rows x 123 columns]

# %% [markdown]
# # Primeiro experimento - 5 Classes

# %%
#remove as colunas referentes às medidas f1m e auc
data.drop(data.filter(regex='(.*?\.auc|.*?\.f1m)').columns, axis=1, inplace=True)
data.loc[:, ['landmarking.randomNode.sd', 'landmarking.worstNode.mean', 'landmarking.worstNode.sd', 'ANN.acc', 
             'C4.5.acc', 'kNN.acc', 'SVM.acc', 'RF.acc']]
# Out:
#      landmarking.randomNode.sd  landmarking.worstNode.mean  \
# 0                     0.038789                    0.886667
# 1                     0.089963                    0.617662
# 2                     0.123754                    0.560536
# 3                     0.160420                    0.639048
# 4                     0.110580                    0.604069
# ..                         ...                         ...
# 395                   0.160472                    0.636310
# 396                   0.018734                    0.700249
# 397                   0.041359                    0.742169
# 398                   0.008433                    0.900000
# 399                   0.107194                    0.672759
#
#      landmarking.worstNode.sd   ANN.acc  C4.5.acc   kNN.acc   SVM.acc  \
# 0                    0.041425  1.000000  0.992000  1.000000  1.000000
# 1                    0.076761  0.708379  0.784846  0.789214  0.770022
# 2                    0.119251  0.837292  0.792357  0.807071  0.846863
# 3                    0.171734  0.767238  0.646000  0.663429  0.761619
# 4                    0.075009  0.961919  0.949307  0.942531  0.966627
# ..                        ...       ...       ...       ...       ...
# 395                  0.179899  0.770893  0.765179  0.768214  0.697202
# 396                  0.018734  0.999768  0.950167  0.877835  0.957931
# 397                  0.042820  0.982605  0.962633  0.970795  0.979193
# 398                  0.000000  0.994850  0.983450  0.993950  0.994550
# 399                  0.138320  0.949768  0.836005  0.858469  0.973110
#
#        RF.acc
# 0    1.000000
# 1    0.848485
# 2    0.866887
# 3    0.785238
# 4    0.965199
# ..        ...
# 395  0.798333
# 396  0.989701
# 397  0.986998
# 398  0.988250
# 399  0.888952
#
# [400 rows x 8 columns]

# %%
#remove as amostras com empate (com relação à maior acurácia) e determina as classes
data = drop_draw_set_class(data.copy())
data.loc[:, ['landmarking.randomNode.mean', 'landmarking.randomNode.sd', 'landmarking.worstNode.mean', 'landmarking.worstNode.sd', 'Class']]
# Out:
#      landmarking.randomNode.mean  landmarking.randomNode.sd  \
# 0                       0.655297                   0.089963
# 1                       0.593000                   0.123754
# 2                       0.569762                   0.160420
# 3                       0.674139                   0.110580
# 4                       0.648228                   0.142807
# ..                           ...                        ...
# 378                     0.676190                   0.160472
# 379                     0.700249                   0.018734
# 380                     0.752254                   0.041359
# 381                     0.903000                   0.008433
# 382                     0.647893                   0.107194
#
#      landmarking.worstNode.mean  landmarking.worstNode.sd    Class
# 0                      0.617662                  0.076761   RF.acc
# 1                      0.560536                  0.119251   RF.acc
# 2                      0.639048                  0.171734   RF.acc
# 3                      0.604069                  0.075009  SVM.acc
# 4                      0.643772                  0.147598  ANN.acc
# ..                          ...                       ...      ...
# 378                    0.636310                  0.179899   RF.acc
# 379                    0.700249                  0.018734  ANN.acc
# 380                    0.742169                  0.042820   RF.acc
# 381                    0.900000                  0.000000  ANN.acc
# 382                    0.672759                  0.138320  SVM.acc
#
# [383 rows x 5 columns]

# %%
#plota distribuição das classes
X = data.drop('Class', axis=1)

y = data['Class']

vec = list(zip( *[*Counter( y ).items()])) 
gambs = pd.DataFrame(dict(zip(['lab', 'val'],vec))) 
ax = gambs.plot.bar(x='lab', y='val', rot=0) 
plt.show(block=True)

# %%
Counter(y)
# Out:
# Counter({'RF.acc': 162,
#          'SVM.acc': 95,
#          'ANN.acc': 61,
#          'kNN.acc': 15,
#          'C4.5.acc': 50})

# %%
rfc = RandomForestClassifier(n_estimators=1000)
k = 0
acc = 0
acc_sum = 0   
n_splits = 3

skf = StratifiedKFold(n_splits=n_splits)
features_list = []
for train_index, test_index in skf.split(X, y):
      k += 1  
      print("Fold ", k)
      rfc.fit(X.loc[train_index, :].drop('index', axis=1), y.loc[train_index])
      features_list.append(rfc.feature_importances_)
      y_pred = rfc.predict(X.loc[test_index, :].drop('index', axis=1), )

      #avaliação da predição

      #acurácia
      acc = accuracy_score(y_true=y.loc[test_index], y_pred=y_pred)
      acc_sum += acc
      print(f"Accuracy: {acc} \n")

      #matriz de confusão
      print("Confusion matrix")  
      disp = plot_confusion_matrix(rfc, X.loc[test_index, :].drop('index', axis=1), y.loc[test_index],
                                 display_labels=None,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
      plt.show()
      print("\n \n")

      


#printa as médias das medidas tiradas nos 10 folds
print("------------------------")
print("Considered classes : All \n")
print("Mean accuracy = ", acc_sum / n_splits, "\n")
# Out:
# Fold  1
# Accuracy: 0.4140625
#
# Confusion matrix
#
#
# Fold  2
# Accuracy: 0.4609375
#
# Confusion matrix
#
#
# Fold  3
# Accuracy: 0.5118110236220472
#
# Confusion matrix
#
#
# ------------------------
# Considered classes : All
#
# Mean accuracy =  0.46227034120734906

# %%
# print(len(X.columns))
# print(len(features_list[0]))
# print(*zip(X.columns[1:], features_list[0]))

for idx, ft_lis in enumerate(features_list):
    print(f"{idx} |----> ")
    for i, j in sorted(zip(X.columns[1:], ft_lis), key = lambda x : x[1], reverse=True)[:10]:
        print(i, ' -> ', j)
    print("\n")
#     break
# Out:
# 0 |---->
# infotheo.attrConc.sd  ->  0.016798693611971754
# landmarking.eliteNN.mean  ->  0.016345391871111337
# model.based.varImportance.mean  ->  0.015987263923707407
# model.based.nodesPerAttr  ->  0.01576318142048178
# infotheo.mutInf.sd  ->  0.015001952925340529
# infotheo.eqNumAttr  ->  0.014822332818446792
# landmarking.oneNN.mean  ->  0.014673311507690828
# statistical.canCor.mean  ->  0.014589083460866323
# general.nrAttr  ->  0.014498562915319788
# model.based.varImportance.sd  ->  0.014480990934313901
#
#
# 1 |---->
# model.based.varImportance.mean  ->  0.025089294362324654
# general.nrAttr  ->  0.01974331574082162
# statistical.nrNorm  ->  0.01892750403226586
# infotheo.attrConc.sd  ->  0.018655393122560895
# infotheo.eqNumAttr  ->  0.017866725307037517
# general.nrNum  ->  0.015886813879529612
# landmarking.naiveBayes.mean  ->  0.01551923835983467
# landmarking.oneNN.mean  ->  0.015462126215641305
# infotheo.mutInf.sd  ->  0.015290954548682538
# landmarking.linearDiscr.mean  ->  0.014925077055969755
#
#
# 2 |---->
# general.nrAttr  ->  0.019063732749202044
# model.based.varImportance.mean  ->  0.0182395349089756
# model.based.varImportance.sd  ->  0.01817031531986444
# landmarking.linearDiscr.mean  ->  0.017224756994415138
# statistical.nrNorm  ->  0.01658675937123589
# infotheo.attrConc.sd  ->  0.01599062538691772
# model.based.nodesPerInst  ->  0.01573261939693657
# statistical.skewness.mean  ->  0.01543576779702378
# landmarking.randomNode.mean  ->  0.01518526423630805
# landmarking.worstNode.mean  ->  0.013958908959656194

# %%
for feat in features_list:    
    plt.bar(list(range(1, 11)), 
            height=list(map(abs, sorted(feat)))[:10], 
            width=0.3)
    plt.show()

# %%
for feat in features_list:
    plt.plot(sorted(feat)[:10], marker='o', markersize=12,
            color='green')
    plt.show()

# %% [markdown]
# # Segundo experimento - Classes dois a dois

# %%
comb_to_drop = list(combinations(ALL_ACC, r=3))
raw = pd.read_csv('meta-base.csv')

classifiers_list = []
acc_mean_list = []

#para cada combinação de 3 colunas, dropa essas 3 deixando 2 colunas para o problema de classificação
#faz o pre_processamento do dataframe passando as colunas consideradas (retira os empates e seta as classes)
#divide o data em features e rótulo e divide os folds
for to_drop in comb_to_drop:
    data = raw.drop(list(to_drop), axis=1)
    considered_classes = ALL_ACC_SET - set(to_drop)
    data = preprocess_default(data, list(considered_classes))
    rfc = RandomForestClassifier(n_estimators=200)
    X = data.drop('Class', axis=1)
    y = data['Class']
    k = 0
    n_splits = 3
    skf = StratifiedKFold(n_splits=n_splits)
    acc = 0
    acc_sum = 0
    classifiers_list.append([])
    print("Considered classes")
    print_counter(y)
    print("\n")
    
    for train_index, test_index in skf.split(X, y):
        k += 1
        print("Fold ", k)
        rfc.fit(X.loc[train_index, :], y.loc[train_index])
        y_pred = rfc.predict(X.loc[test_index, :], )

        #avaliação da predição

        #acurácia
        acc = accuracy_score(y_true=y.loc[test_index], y_pred=y_pred)
        acc_sum += acc
        print(f"Accuracy: {acc} \n")

        #matriz de confusão
        disp = plot_confusion_matrix(rfc, X.loc[test_index, :], y.loc[test_index],
                                 display_labels=None,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
        plt.show()
        print("\n \n")

        classifiers_list[-1].append(rfc)

        
    
    print("Mean accuracy = ", acc_sum / n_splits, "\n")
    acc_mean_list.append(acc_sum / n_splits)
    print("-----------------------\n")
# Out:
# Considered classes
# RF.acc -> 246
# SVM.acc -> 151
#
#
# Fold  1
# Accuracy: 0.47368421052631576
#
#
# Fold  2
# Accuracy: 0.6666666666666666
#
#
# Fold  3
# Accuracy: 0.6666666666666666
#
#
# Mean accuracy =  0.6023391812865496
#
# -----------------------
#
# Considered classes
# RF.acc -> 304
# C4.5.acc -> 89
#
#
# Fold  1
# Accuracy: 0.7786259541984732
#
#
# Fold  2
# Accuracy: 0.7557251908396947
#
#
# Fold  3
# Accuracy: 0.7633587786259542
#
#
# Mean accuracy =  0.7659033078880407
#
# -----------------------
#
# Considered classes
# SVM.acc -> 230
# C4.5.acc -> 165
#
#
# Fold  1
# Accuracy: 0.6287878787878788
#
#
# Fold  2
# Accuracy: 0.6666666666666666
#
#
# Fold  3
# Accuracy: 0.6335877862595419
#
#
# Mean accuracy =  0.6430141105713624
#
# -----------------------
#
# Considered classes
# RF.acc -> 347
# kNN.acc -> 49
#
#
# Fold  1
# Accuracy: 0.8636363636363636
#
#
# Fold  2
# Accuracy: 0.8712121212121212
#
#
# Fold  3
# Accuracy: 0.8712121212121212
#
#
# Mean accuracy =  0.8686868686868686
#
# -----------------------
#
# Considered classes
# kNN.acc -> 79
# SVM.acc -> 317
#
#
# Fold  1
# Accuracy: 0.8181818181818182
#
#
# Fold  2
# Accuracy: 0.8333333333333334
#
#
# Fold  3
# Accuracy: 0.8181818181818182
#
#
# Mean accuracy =  0.8232323232323232
#
# -----------------------
#
# Considered classes
# kNN.acc -> 120
# C4.5.acc -> 277
#
#
# Fold  1
# Accuracy: 0.6541353383458647
#
#
# Fold  2
# Accuracy: 0.7727272727272727
#
#
# Fold  3
# Accuracy: 0.7348484848484849
#
#
# Mean accuracy =  0.7205703653072074
#
# -----------------------
#
# Considered classes
# RF.acc -> 271
# ANN.acc -> 118
#
#
# Fold  1
# Accuracy: 0.6923076923076923
#
#
# Fold  2
# Accuracy: 0.7384615384615385
#
#
# Fold  3
# Accuracy: 0.7286821705426356
#
#
# Mean accuracy =  0.7198171337706221
#
# -----------------------
#
# Considered classes
# SVM.acc -> 225
# ANN.acc -> 170
#
#
# Fold  1
# Accuracy: 0.6212121212121212
#
#
# Fold  2
# Accuracy: 0.6136363636363636
#
#
# Fold  3
# Accuracy: 0.4961832061068702
#
#
# Mean accuracy =  0.577010563651785
#
# -----------------------
#
# Considered classes
# ANN.acc -> 214
# C4.5.acc -> 178
#
#
# Fold  1
# Accuracy: 0.6564885496183206
#
#
# Fold  2
# Accuracy: 0.7099236641221374
#
#
# Fold  3
# Accuracy: 0.7153846153846154
#
#
# Mean accuracy =  0.6939322763750244
#
# -----------------------
#
# Considered classes
# kNN.acc -> 82
# ANN.acc -> 313
#
#
# Fold  1
# Accuracy: 0.6515151515151515
#
#
# Fold  2
# Accuracy: 0.8181818181818182
#
#
# Fold  3
# Accuracy: 0.7938931297709924
#
#
# Mean accuracy =  0.7545300331559873
#
# -----------------------

# %%
data_rf_all = drop_all_vs_rf(pd.read_csv('meta-base.csv'))
data_rf_all.drop(data_rf_all.filter(regex='(.*?\.auc|.*?\.f1m)').columns, axis=1, inplace=True)
data_rf_all

classifiers_list_all = []
acc_mean_list_all = []

#para cada combinação de 3 colunas, dropa essas 3 deixando 2 colunas para o problema de classificação
#faz o pre_processamento do dataframe passando as colunas consideradas (retira os empates e seta as classes)
#divide o data em features e rótulo e divide os folds
data = data_rf_all
rfc = RandomForestClassifier(n_estimators=1000)
X = data.drop('Class', axis=1)
y = data['Class']
k = 0
n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, random_state=42, shuffle=True)
acc = 0
acc_sum = 0
classifiers_list_all.append([])
print("Considered classes")
print_counter(y)
print("\n")

for train_index, test_index in skf.split(X, y):
    k += 1
    print("Fold ", k)
    rfc.fit(X.loc[train_index, :], y.loc[train_index])
    y_pred = rfc.predict(X.loc[test_index, :], )

    #avaliação da predição

    #acurácia
    acc = accuracy_score(y_true=y.loc[test_index], y_pred=y_pred)
    acc_sum += acc
    print(f"Accuracy: {acc} \n")

    #matriz de confusão
    disp = plot_confusion_matrix(rfc, X.loc[test_index, :], y.loc[test_index],
                             display_labels=None,
                             cmap=plt.cm.Blues,
                             normalize=None)
    plt.show()
    print("\n \n")

    classifiers_list_all[-1].append(rfc)



print("Mean accuracy = ", acc_sum / n_splits, "\n")
acc_mean_list_all.append(acc_sum / n_splits)
print("-----------------------\n")
# Out:
# Considered classes
# RF.acc -> 162
# Other -> 221
#
#
# Fold  1
# Accuracy: 0.6666666666666666
#
#
# Fold  2
# Accuracy: 0.48717948717948717
#
#
# Fold  3
# Accuracy: 0.717948717948718
#
#
# Fold  4
# Accuracy: 0.7368421052631579
#
#
# Fold  5
# Accuracy: 0.7894736842105263
#
#
# Fold  6
# Accuracy: 0.5789473684210527
#
#
# Fold  7
# Accuracy: 0.6842105263157895
#
#
# Fold  8
# Accuracy: 0.6842105263157895
#
#
# Fold  9
# Accuracy: 0.6842105263157895
#
#
# Fold  10
# Accuracy: 0.7368421052631579
#
#
# Mean accuracy =  0.6766531713900135
#
# -----------------------
